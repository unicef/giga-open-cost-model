# %% [markdown]
# ## Tower Data
# The table below highlights lat/lon entries in the cellular data that may be erroneous.
# Namely overly large lat and lon values that seem to have their decimals in the wrong place.
# These have been cleaned up in the following way:
# * Lat values in the -150_000 range have been trasnformed into -1.5... by shifting the decimal
# * Lon values in the 3_000_000 range have been turned into 30... by shifting the decimal

# %%
import pandas as pd
from giga.schemas.cellular import CellTowerTable

towers = CellTowerTable.from_csv('../parameter_workspace/IHS-RWD.csv')
dft = pd.DataFrame(list(map(lambda x: dict(x), towers.towers)))
dft
# Out:
#           tower_id operator  outdoor      lat       lon  height  technologies
# 0     IHS_STH_069M      IHS     True -2.61522  29.46072    36.0  [2G, 3G, 4G]
# 1     IHS_STH_042M      IHS    False -2.59830  29.74199     6.0      [2G, 3G]
# 2     IHS_STH_025M      IHS    False -2.48961  29.77220    36.0  [2G, 3G, 4G]
# 3     IHS_STH_036M      IHS     True -2.48449  29.85669    36.0      [2G, 3G]
# 4     IHS_STH_092M      IHS     True -2.78618  29.67667    54.0  [2G, 3G, 4G]
# ...            ...      ...      ...      ...       ...     ...           ...
# 1202  IHS_KGL_385M      IHS     True -1.92117  30.05715    18.0      [2G, 3G]
# 1203  IHS_KGL_395M      IHS     True -1.94995  30.08169    30.0      [2G, 3G]
# 1204  IHS_KGL_478M      IHS     True -1.91317  30.07819     7.0      [2G, 3G]
# 1205  IHS_KGL_480M      IHS     True -1.93399  30.16299    30.0      [2G, 3G]
# 1206  IHS_KGL_482M      IHS     True -1.92579  30.14731    30.0      [2G, 3G]
#
# [1207 rows x 7 columns]

# %%
dft.query('lat < -3')
# Out:
#          tower_id operator  outdoor       lat           lon  height  \
# 853  IHS_NTH_114M      IHS     True -152506.0  3.009266e+01    36.0
# 854  IHS_NTH_115M      IHS     True -149783.0  3.000120e+01    36.0
# 898  IHS_NTH_125M      IHS     True -139734.0  3.007836e+06    36.0
#
#     technologies
# 853     [2G, 3G]
# 854     [2G, 3G]
# 898     [2G, 3G]

# %%
dft.query('lon > 35')
# Out:
#          tower_id operator  outdoor           lat         lon  height  \
# 898  IHS_NTH_125M      IHS     True -139734.00000   3007836.0    36.0
# 916  IHS_STH_155M      IHS     True      -2.28374  29657623.0    36.0
#
#     technologies
# 898     [2G, 3G]
# 916     [2G, 3G]

# %% [markdown]
# ## Cleaned Up Data
# Cleaned up data and plots below.

# %%
import pandas as pd
from giga.schemas.cellular import CellTowerTable

towers = CellTowerTable.from_csv('../parameter_workspace/IHS-RWD-clean.csv')
dft = pd.DataFrame(list(map(lambda x: dict(x), towers.towers)))
dft
# Out:
#           tower_id operator  outdoor      lat       lon  height  technologies
# 0     IHS_STH_069M      IHS     True -2.61522  29.46072    36.0  [2G, 3G, 4G]
# 1     IHS_STH_042M      IHS    False -2.59830  29.74199     6.0      [2G, 3G]
# 2     IHS_STH_025M      IHS    False -2.48961  29.77220    36.0  [2G, 3G, 4G]
# 3     IHS_STH_036M      IHS     True -2.48449  29.85669    36.0      [2G, 3G]
# 4     IHS_STH_092M      IHS     True -2.78618  29.67667    54.0  [2G, 3G, 4G]
# ...            ...      ...      ...      ...       ...     ...           ...
# 1202  IHS_KGL_385M      IHS     True -1.92117  30.05715    18.0      [2G, 3G]
# 1203  IHS_KGL_395M      IHS     True -1.94995  30.08169    30.0      [2G, 3G]
# 1204  IHS_KGL_478M      IHS     True -1.91317  30.07819     7.0      [2G, 3G]
# 1205  IHS_KGL_480M      IHS     True -1.93399  30.16299    30.0      [2G, 3G]
# 1206  IHS_KGL_482M      IHS     True -1.92579  30.14731    30.0      [2G, 3G]
#
# [1207 rows x 7 columns]

# %%
from giga.schemas.school import GigaSchoolTable

schools = GigaSchoolTable.from_csv('../sample_workspace/rwanda/schools.csv')
pd.DataFrame(list(map(lambda x: dict(x), schools.schools)))
# Out:
#      school_id                            name country  country_id       lat  \
# 0       450302            ACADEMIE DE LA SALLE  Rwanda          32 -1.572110
# 1       270601               ACODES MUSHISHIRO  Rwanda          32 -2.006444
# 2       270853           ADEPR GIFUMBA NURSARY  Rwanda          32 -2.104440
# 3       520601                   ADEPR MATIMBA  Rwanda          32 -1.115083
# 4       270802      AHAZAZA INDEPENDENT SCHOOL  Rwanda          32 -2.080920
# ...        ...                             ...     ...         ...       ...
# 4189    121012  WORLD MISSION SECONDARY SCHOOL  Rwanda          32 -1.916690
# 4190    110824           YATIMA NURSERY SCHOOL  Rwanda          32 -1.979300
# 4191    370114             YOVE PRIMARY SCHOOL  Rwanda          32 -2.443420
# 4192    561410                     ZAZA B  P/S  Rwanda          32 -2.154444
# 4193    270117           ZION EDUCATION CENTER  Rwanda          32 -2.072830
#
#             lon admin_1_name admin_2_name admin_3_name admin_4_name  \
# 0     30.050560      GICUMBI       BYUMBA    NYAMABUYE
# 1     29.691194      MUHANGA   MUSHISHIRO       MUNAZI
# 2     29.728890      MUHANGA    NYAMABUYE      GIFUMBA
# 3     30.426000    NYAGATARE      MATIMBA      BYIMANA
# 4     29.751310      MUHANGA    NYAMABUYE       GAHOGO
# ...         ...          ...          ...          ...          ...
# 4189  30.089170       GASABO     KINYINYA     GACURIRO
# 4190  30.037000   NYARUGENGE   NYAMIRAMBO    CYIVUGIZA
# 4191  29.066720   NYAMASHEKE    BUSHEKERI    BUVUNGIRA
# 4192  30.431667        NGOMA         ZAZA      RUHEMBE
# 4193  29.782080      MUHANGA        CYEZA       MAKERA
#
#      education_level                               giga_id school_zone  \
# 0          Secondary  1e5e0921-4d5e-4afe-a163-1d9477a1ee2a
# 1          Secondary  54cf6c4a-a096-4ae9-b27c-bd43eef634d3
# 2            Primary  3ad3de39-494d-45bf-a969-13f9360aa912
# 3            Primary  cddf1ef8-f5cd-4d39-b91b-0ad1b84b1997
# 4            Primary  ccb61cc2-03f9-47b4-9ae3-13f9eed30aa9
# ...              ...                                   ...         ...
# 4189       Secondary  3f383164-98d5-4b3e-815e-461a33bdcc5d
# 4190         Primary  f9a940d4-496b-4938-a071-0eed9a4e72b5
# 4191         Primary  6da9c5ec-a882-4250-8d0b-3c8340c061ff
# 4192         Primary  9fbde5f8-f9bb-407d-b411-2e00e1a39fd9
# 4193         Primary  f03903f1-a38f-4d80-a75a-fe41ab81821f
#
#       connected connectivity_status  has_electricity  bandwidth_demand
# 0          True                Good             True              20.0
# 1          True                Good             True              20.0
# 2         False       No connection             True              20.0
# 3         False       No connection             True              20.0
# 4          True                Good             True              20.0
# ...         ...                 ...              ...               ...
# 4189       True                Good             True              20.0
# 4190      False       No connection             True              20.0
# 4191       True            Moderate             True              20.0
# 4192       True                Good             True              20.0
# 4193      False       No connection            False              20.0
#
# [4194 rows x 17 columns]

# %%
from giga.models.nodes.graph.pairwise_distance_model import PairwiseDistanceModel

tower_coords = towers.to_coordinates()
school_coords = schools.to_coordinates()

m = PairwiseDistanceModel()
distances = m.run((school_coords, tower_coords))

# %%
closest = {}
for d in distances:
    sid = d.coordinate1.coordinate_id
    if sid not in closest:
        closest[sid] = [d.distance]
    else:
        closest[sid].append(d.distance)

# %%
cl = [min(v) / 1000.0 for v in closest.values()]

# %%
import matplotlib.pyplot as plt

plt.hist(cl, bins=20)
plt.grid()
plt.xlabel('Distance to Closest Cell Tower (km)')
plt.ylabel('School Counts')
plt.show()

# %%
from giga.viz.notebooks.fiber import plot_data_map, default_rwanda_map

plot_data_map([], tower_coords, school_coords, m=default_rwanda_map())
